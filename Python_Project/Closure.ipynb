# %% [markdown]
# Closure

# %%
def print_message(msg):
    def printer():
        print (msg)
    printer()
print_message("Hello")
# Out:
# Hello

# %%
def print_message(msg):
    def printer():
        print (msg)
    return printer
another = print_message("Hello")
another()
# Out:
# Hello
